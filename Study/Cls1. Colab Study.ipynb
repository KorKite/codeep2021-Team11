# %% [markdown]
# # What is Colab
#     파이썬을 line by line으로 실행해 볼 수 있는 노트북
#     GPU를 활용할 수 있어서 딥러닝 서버를 구축하지 않고도 딥러닝을 해볼 수 있다는 장점 때문에
#     최근 많이 사용되고 있다.
#
#     또한, 로컬 머신이 안좋은 경우, 코랩을 활용하여 성능 좋은 컴퓨터를 활용할 수 있다.
#     linux명령어 등도 활용이 가능하다.

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Linux Command in Colab

# %%
# !ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Apr  7 13:36 .
# drwxr-xr-x 1 root root 4096 Apr 14 04:13 ..
# drwxr-xr-x 4 root root 4096 Apr  7 13:35 .config
# drwxr-xr-x 1 root root 4096 Apr  7 13:36 sample_data

# %%
# !wget https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2021/04/featured-image-for-7zip-on-Linux.jpg?q=50&fit=contain&w=750&h=375&dpr=1.5
# Out:
# --2021-04-14 04:33:37--  https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2021/04/featured-image-for-7zip-on-Linux.jpg?q=50
# Resolving static1.makeuseofimages.com (static1.makeuseofimages.com)... 104.22.45.121, 104.22.44.121, 172.67.39.79, ...
# Connecting to static1.makeuseofimages.com (static1.makeuseofimages.com)|104.22.45.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70983 (69K) [image/jpeg]
# Saving to: ‘featured-image-for-7zip-on-Linux.jpg?q=50’
#
# featured-image-for- 100%[===================>]  69.32K  --.-KB/s    in 0.01s
#
# 2021-04-14 04:33:37 (4.96 MB/s) - ‘featured-image-for-7zip-on-Linux.jpg?q=50’ saved [70983/70983]

# %% [markdown]
# # Colab Data Load and Export

# %% [markdown]
# ### Data Load into Colab, via google drive

# %%
with open("/content/drive/MyDrive/Co-Deep Learning/server_210117_115406.log") as l:
    print(l.readline())
# Out:
# [INFO|2021-01-17 11:54:06,236] EngineController server starting at localhost:35000
